# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# โหลดข้อมูล
dataset = pd.read_csv('Social_Network_Adsnew.csv')

# แปลงตัวแปรเพศ (Gender) เป็นตัวเลข
dataset['Gender'] = dataset['Gender'].map({'Male': 0, 'Female': 1})

# แยก features และ labels
X = dataset[['Age', 'EstimatedSalary', 'Gender']].values
y = dataset['Purchased'].values

# แยกชุดข้อมูลสำหรับเทรนและทดสอบ
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# การทำ Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# สร้างโมเดล Decision Tree
classifier = DecisionTreeClassifier(criterion='entropy', random_state=0)
classifier.fit(X_train, y_train)

# ทำนายผล
y_pred = classifier.predict(X_test)

# การประเมินผล
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
print("Accuracy:", accuracy)

# Visualize the training set results
X_set, y_set = sc.inverse_transform(X_train), y_train

# Set a constant gender value (0 for Male, 1 for Female)
gender_value = 0  # Change to 1 if you want to visualize for Female

# Define meshgrid ranges correctly
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10, step=1),
                     np.arange(start=X_set[:, 1].min() - 1000, stop=X_set[:, 1].max() + 1000, step=100))

# Create a grid with the gender constant value
grid = np.array([X1.ravel(), X2.ravel(), np.full(X1.ravel().shape, gender_value)]).T

# Plot decision boundary
plt.contourf(X1, X2, classifier.predict(sc.transform(grid)).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))

# Set plot limits
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Plot data points
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1], c=ListedColormap(('red', 'green'))(i), label=j)

# Labels and title
plt.title('Decision Tree Classification (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')

# Show legend
plt.legend()

# Show plot
plt.show()

# Visualize the test set results
X_set, y_set = sc.inverse_transform(X_test), y_test

# Set a constant gender value (0 for Male, 1 for Female)
gender_value = 0  # Change to 1 if you want to visualize for Female

# Define meshgrid ranges correctly
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10, step=1),
                     np.arange(start=X_set[:, 1].min() - 1000, stop=X_set[:, 1].max() + 1000, step=100))

# Create a grid with the gender constant value
grid = np.array([X1.ravel(), X2.ravel(), np.full(X1.ravel().shape, gender_value)]).T

# Plot decision boundary
plt.contourf(X1, X2, classifier.predict(sc.transform(grid)).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))

# Set plot limits
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Plot data points
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1], c=ListedColormap(('red', 'green'))(i), label=j)

# Labels and title
plt.title('Decision Tree Classification (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')

# Show legend
plt.legend()

# Show plot
plt.show()
# Out:
# Confusion Matrix:
# [[62  6]
#  [ 4 28]]
# Accuracy: 0.9
# C:\Users\kittinun\AppData\Local\Temp\ipykernel_28824\259188075.py:65: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1], c=ListedColormap(('red', 'green'))(i), label=j)
# C:\Users\kittinun\AppData\Local\Temp\ipykernel_28824\259188075.py:101: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
# Visualize the training set results
X_set, y_set = sc.inverse_transform(X_train), y_train

# Set a constant gender value (0 for Male, 1 for Female)
gender_value = 1  # Change to 1 if you want to visualize for Female

# Define meshgrid ranges correctly
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10, step=1),
                     np.arange(start=X_set[:, 1].min() - 1000, stop=X_set[:, 1].max() + 1000, step=100))

# Create a grid with the gender constant value
grid = np.array([X1.ravel(), X2.ravel(), np.full(X1.ravel().shape, gender_value)]).T

# Plot decision boundary
plt.contourf(X1, X2, classifier.predict(sc.transform(grid)).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))

# Set plot limits
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Plot data points
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1], c=ListedColormap(('red', 'green'))(i), label=j)

# Labels and title
plt.title('Decision Tree Classification (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')

# Show legend
plt.legend()

# Show plot
plt.show()

# Visualize the test set results
X_set, y_set = sc.inverse_transform(X_test), y_test

# Set a constant gender value (0 for Male, 1 for Female)
gender_value = 1  # Change to 1 if you want to visualize for Female

# Define meshgrid ranges correctly
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10, step=1),
                     np.arange(start=X_set[:, 1].min() - 1000, stop=X_set[:, 1].max() + 1000, step=100))

# Create a grid with the gender constant value
grid = np.array([X1.ravel(), X2.ravel(), np.full(X1.ravel().shape, gender_value)]).T

# Plot decision boundary
plt.contourf(X1, X2, classifier.predict(sc.transform(grid)).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))

# Set plot limits
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Plot data points
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1], c=ListedColormap(('red', 'green'))(i), label=j)

# Labels and title
plt.title('Decision Tree Classification (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')

# Show legend
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\kittinun\AppData\Local\Temp\ipykernel_28824\2599710581.py:24: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1], c=ListedColormap(('red', 'green'))(i), label=j)
# C:\Users\kittinun\AppData\Local\Temp\ipykernel_28824\2599710581.py:60: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
import pickle
pickle.dump(classifier,open("DEE.pkl","wb"))
model_pk=pickle.load(open("DEE.pkl","rb"))
model_pk.predict(sc.transform([[22,120000,1]]))
# Out:
# array([0], dtype=int64)
